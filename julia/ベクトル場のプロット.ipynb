# %%
using PyPlot

# from https://github.com/JuliaLang/julia/blob/master/examples/ndgrid.jl
function meshgrid(vx::AbstractVector{T}, vy::AbstractVector{T}) where T
    m, n = length(vy), length(vx)
    vx = reshape(vx, 1, n)
    vy = reshape(vy, m, 1)
    (repmat(vx, m, 1), repmat(vy, 1, n))
end

xx = [linspace(-2.0,1.0, 751);]
yy = [linspace(-1.5,1.5, 751);]
x, y = meshgrid(xx,yy)
z = x + im*y

tt = [0.48 0.502 0.52]
for t in tt
    
    theta = t*pi
    c = exp(im*theta)
    w = c*sqrt.(1.+z)./z
    
    figure()
    title("\$t = $t\$")
    streamplot(xx,yy,real(w),-imag(w), density=1, linewidth=0.5)
    plot(0,0,"o",color="black")
    plot(-1,0,"x",color="red")
    
    s1 = c*(-0.05)-1
    s2 = c*(0.05+im*0.09)-1
    s = [
         real(s1)  imag(s1)
         real(s2)  imag(s2)
    ]
    streamplot(xx,yy,real(w),-imag(w),linewidth=2, start_points=s)

    xlim(-1.9,0.9)
    ylim(-1.4,1.4)
    axes()[:set_aspect]("equal")

end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13c450898>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13b756898>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13c1c3390>)

# %%
using PyPlot

# from https://github.com/JuliaLang/julia/blob/master/examples/ndgrid.jl
function meshgrid(vx::AbstractVector{T}, vy::AbstractVector{T}) where T
    m, n = length(vy), length(vx)
    vx = reshape(vx, 1, n)
    vy = reshape(vy, m, 1)
    (repmat(vx, m, 1), repmat(vy, 1, n))
end

x,y = ([linspace(-3, 3, 100);],[linspace(-3, 3, 100);])
X, Y = meshgrid(x, y)
U = X-X^3-Y
V = 3X-2Y
#U = -1 .-X.^2 .+ y
#V = 1 .+X .-Y.^2
speed = sqrt.(U.*U + V.*V)
start = [0 0; 1 2]
streamplot(x, y, U, V)
#streamplot(x, y, U, V, start_points=start)
#plot(start[:,1], start[:, 2], "o")
y2 = x.-(x.^3) -y
y3 = 3x-2y
plot(linspace(-3,3,100),y2)
plot(linspace(-3,3,100),y3)
plt[:xlim](-3.0, 3.0)
plt[:ylim](-3.0, 3.0)
grid("on")
axes()[:set_aspect]("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x14460a5f8>)

# %% [markdown]
# $(x+C)e^{2x}+y^4$(Cは任意定数)の解曲線

# %%
using Plots
C = [-5,-3,-1,0,0.5,1,3,5]
x,y = ([linspace(-3, 3, 100);],[linspace(-3, 3, 100);])
#y=e.^x-(x.^2 .* y.^3)+y.^4-C
#y=(x .+ C).*e.^(2x).+1/2
ims = []
for c in 1:length(C)
    y=(x .+ C[c]).*e.^(2x).+1/2
    push!(ims,x,y)
end
plot(ims,ylims=(-300,300),xlims=(0,100),legend=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 42.8473,375.869 580.315,375.869 580.315,11.811 42.8473,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1102">
#     <rect x="42" y="11" width="538" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.8473,375.869 42.8473,11.811
#   "/>
# ...

# %%
C
# Out:
# 8-element Array{Float64,1}:
#  -5.0
#  -3.0
#  -1.0
#   0.0
#   0.5
#   1.0
#   3.0
#   5.0

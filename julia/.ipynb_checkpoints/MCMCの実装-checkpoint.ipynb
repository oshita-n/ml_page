# %%
import numpy as np
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# %%
b = 0.8 #　相関項
x = 10.0
y = 3.0
times = 200

output_notebook()
p = figure()

for i in range(1, times):
    x_old = x
    x = np.random.normal(b*y, 1.0)
    p.line([x_old, x], [y, y], color="blue",line_width=2)
    y_old = y
    y = np.random.normal(b*x, 1.0)
    p.line([x, x], [y_old, y], color="blue", line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c274c5da-b7ac-4f09-9659-80b505237f0b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6ea8f67-1054-45fe-9e47-16be75f17370"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c6ea8f67-1054-45fe-9e47-16be75f17370");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6ea8f67-1054-45fe-9e47-16be75f17370");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6ea8f67-1054-45fe-9e47-16be75f17370' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"65640e7f-7867-4bc7-9d07-67a411e6c0ae":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"dfac5d35-d80d-4fee-8f44-109fdcce0d26","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2e880d63-3e88-4789-81a3-26ae3dc596a1","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c73d984a-e616-4f4a-a5f3-c54ceff6c98e","type":"Line"},{"attributes":{"source":{"id":"f94a6db3-3566-4cf2-a414-e88496949e38","type":"ColumnDataSource"}},"id":"d8761c20-6b82-412d-a973-84edd26abd25","type":"CDSView"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac0a31c1-c42b-405f-ad6d-0374db55cbca","type":"Line"},{"attributes":{"source":{"id":"56758bc6-b607-40d4-95e9-2f04e19d474a","type":"ColumnDataSource"}},"id":"fa897838-96a7-4d27-a526-e358999e4400","type":"CDSView"},{"attributes":{"source":{"id":"1863fb63-f157-4de8-9133-15bc53508d85","type":"ColumnDataSource"}},"id":"d396d371-3c03-43c1-abf6-81f967f1125a","type":"CDSView"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee37d46b-4ccd-40d4-861c-18b81b11d7d4","type":"Line"},{"attributes":{"source":{"id":"692b9d8d-5071-46c3-8eee-383b51d85e5a","type":"ColumnDataSource"}},"id":"3183bc21-eafd-4871-a1d7-62e189c5bfa6","type":"CDSView"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8fc820c9-3c0e-44f5-9363-3032f411e4e4","type":"Line"},{"attributes":{"data_source":{"id":"e50f824e-3a49-4eee-bb5a-138b7f483ee6","type":"ColumnDataSource"},"glyph":{"id":"aaa9534f-4026-4052-b3e4-e41807c43198","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98822572-b782-4e88-b8e5-09a414eee836","type":"Line"},"selection_glyph":null,"view":{"id":"e92313c8-0bf7-40d9-b6e3-aaaa6850d9eb","type":"CDSView"}},"id":"94fccb0c-4708-4e34-a73d-6f22f02d373a","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"09dfb854-2edb-4699-a712-b12124a3e272","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1257e075-4984-4a88-92c0-bc1a04d5b07a","type":"Line"},{"attributes":{"data_source":{"id":"d8d5b516-9173-4ff2-9991-1dd8588b017e","type":"ColumnDataSource"},"glyph":{"id":"47294291-a3ba-4655-a6ca-5a766618b70d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"40be5bea-fdc7-44a9-a2ca-5c9c39968f23","type":"Line"},"selection_glyph":null,"view":{"id":"5436963e-525f-4b11-a4b3-cc52941968f0","type":"CDSView"}},"id":"10ae91d1-9da0-48b5-8d80-af1446bd6d37","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.5987558637940439,1.799498102339464],"y":[-0.1927014566546026,-0.1927014566546026]}},"id":"5a6c2367-19fa-44d6-9aaf-e71e7e6b9263","type":"ColumnDataSource"},{"attributes":{"source":{"id":"4c8a28b4-c179-4bdb-a078-b34d2aaa270e","type":"ColumnDataSource"}},"id":"096b5ee7-c626-441a-a54d-50692ea4befa","type":"CDSView"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"de66939b-707b-44e4-96e5-5e5a32033314","type":"Line"},{"attributes":{"source":{"id":"8d6f6159-ca8c-40b1-9891-e1865ad51005","type":"ColumnDataSource"}},"id":"9f6affcf-9708-4325-b6a3-2b6daa183bac","type":"CDSView"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"e9a88161-a1fe-4cb7-8265-fad24d416efb","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"fi ...

# %%
#  ボックスミューラー法による実装．

b = 0.8 # 相関項
x = 10.0
y = 3.0
times = 150

output_notebook()
p = figure()

for i in range(1, times):
    u1 = np.random.rand()
    u2 = np.random.rand()
    x_old = x
    x = np.sqrt(-2*np.log(u1))*np.cos(2*np.pi*u2) + b*y
    p.line([x_old, x], [y, y], color="blue",line_width=2)
    y_old = y
    y = np.sqrt(-2*np.log(u1))*np.sin(2*np.pi*u2)  + b*x
    p.line([x, x], [y_old, y], color="blue", line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c45eaeab-aa89-4810-839e-bd3ddb250da3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2074e9b4-fe48-4988-89ed-ec6aa4ef4dc9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("2074e9b4-fe48-4988-89ed-ec6aa4ef4dc9");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2074e9b4-fe48-4988-89ed-ec6aa4ef4dc9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2074e9b4-fe48-4988-89ed-ec6aa4ef4dc9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f3721267-a4f1-45d1-93c0-e52f038c65f7":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-1.746623474515545,0.31371472725392835],"y":[-0.5237227063242302,-0.5237227063242302]}},"id":"6f3cc3cc-962b-4925-8a61-8782b34ee509","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ed1e79c-6e30-40fc-bdcd-0bffb82f2bfa","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-2.7920410310770256,-2.7920410310770256],"y":[-0.5769852167384949,-2.3993913943156553]}},"id":"02b8a418-c776-4d1f-84b9-a5c4ccec7d41","type":"ColumnDataSource"},{"attributes":{"source":{"id":"1cd55573-305f-4a91-aa22-514d186e4a89","type":"ColumnDataSource"}},"id":"80729517-8d5b-4944-8ff3-f8a748939223","type":"CDSView"},{"attributes":{"data_source":{"id":"48e47620-90ac-48a8-ac2b-e7419765bfe9","type":"ColumnDataSource"},"glyph":{"id":"e2ccf800-8697-43c5-b57b-a1cc061832c8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cc1b401a-586b-4be2-ba40-4b28baa3ad5f","type":"Line"},"selection_glyph":null,"view":{"id":"b5b3fcc8-434b-4b62-b548-a4a9829a55c0","type":"CDSView"}},"id":"d6ab804d-cbc4-418b-af92-ae6d4c29c1a2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ddc4cf9f-ac6b-4ab6-bc6e-c3ab39c420dd","type":"ColumnDataSource"},"glyph":{"id":"a67efb2a-faf1-48b6-b97f-1d0badef2494","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f53cb6c8-710b-4274-b25d-a69cf7e7aeaa","type":"Line"},"selection_glyph":null,"view":{"id":"72fc2bc1-41ab-46f9-947d-513bb6b1fed7","type":"CDSView"}},"id":"d1b436b3-624c-4d70-a311-29c60756407f","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"34ef253d-cad2-486f-9b67-3adeb333b6ec","type":"Line"},{"attributes":{"data_source":{"id":"137a32f2-1816-4f1f-a4c9-58c769ddf678","type":"ColumnDataSource"},"glyph":{"id":"507223a8-636f-4819-b2e8-1517ed14bcee","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"97871e0d-feff-4778-966f-a5886d554f17","type":"Line"},"selection_glyph":null,"view":{"id":"57288d74-959c-495f-9c1f-bbc80e62351a","type":"CDSView"}},"id":"a4c60274-77f2-40b7-9d3a-b039c5816c39","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"9bceb85b-a81a-4257-bc14-d61e2e2aefe3","type":"ColumnDataSource"},"glyph":{"id":"57e4f9a1-75ea-4479-ade5-699ca4ccf813","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":
subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8914f013-d7c2-4ce8-b321-fba302f1d990","subtype":"Figure","type":"Plot"},"ticker":{"id":"2db02095-5b41-424b-9286-7f3ac18c1c61","type":"BasicTicker"}},"id":"b1eaaf26-9e2e-44ee-9821-56f995cefdb5","type":"Grid"},{"attributes":{},"id":"67ea80de-6974-47f1-b929-29f31e0eaa53","type":"HelpTool"},{"attributes":{"overlay":{"id":"4e250387-2ca5-48dd-b0c5-27563d82f3cf","type":"BoxAnnotation"}},"id":"4a54dd57-0729-40ba-8113-2299e2e80834","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"a9a464df-4875-43f3-8f89-e0e2893e249d","type":"BasicTickFormatter"},"plot":{"id":"8914f013-d7c2-4ce8-b321-fba302f1d990","subtype":"Figure","type":"Plot"},"ticker":{"id":"2db02095-5b41-424b-9286-7f3ac18c1c61","type":"BasicTicker"}},"id":"1213a8e7-d43c-4f8b-9406-d62a65da2a7d","type":"LinearAxis"},{"attributes":{},"id":"2a4dc410-18ea-4e11-bb12-3003b59c753f","type":"BasicTickFormatter"},{"attributes":{},"id":"9a1df5d5-0445-431a-95ac-bc2021d96738","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"891b0e13-e999-4f1a-9a0c-550ee3a66cb4","type":"Title"},{"attributes":{},"id":"d01e593d-67e6-4b27-9678-9b9c447820cc","type":"WheelZoomTool"},{"attributes":{},"id":"079cdca2-9b8b-4ed3-a02a-22527729c49b","type":"ResetTool"},{"attributes":{"f ...

# %%
p = figure()
imax=400
for i in range(1, imax):
    u1 = np.random.rand()
    u2 = np.random.rand()
    
    p.scatter(u1, u2)
show(p)

# %%
np.random.rand()
# Out:
# 0.6564043688589801

# %%
y=2
y_old =1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - b*y)**2 / (2 * sigma**2))
y_old
# Out:
# array([ 0.00914707,  0.01001891,  0.01096165,  0.01197978,  0.01307794,
#         0.01426092,  0.01553363,  0.01690113,  0.0183686 ,  0.01994131,
#         0.02162464,  0.02342403,  0.02534497,  0.02739298,  0.02957361,
#         0.03189237,  0.03435474,  0.03696614,  0.03973186,  0.04265708,
#         0.04574681,  0.04900586,  0.05243879,  0.05604988,  0.05984312,
#         0.06382211,  0.06799009,  0.07234982,  0.07690362,  0.08165327,
#         0.08659998])

# %%
p = figure()
mu, sigma = 0, 0.1
s = np.random.normal(mu, sigma, 100)
p.scatter(s, s)
show(p)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

#  ボックスミューラー法による実装．

b = 0.8 # 相関項
x = 10.0
y = 3.0
times = 200
im = []
ims = []

fig = plt.figure()

for i in range(1, times):
    u1 = np.random.rand()
    u2 = np.random.rand()
    x_old = x
    x = np.sqrt(-2*np.log(u1))*np.cos(2*np.pi*u2) + b*y
    im = im + plt.plot([x_old, x], [y, y], color="blue")
    y_old = y
    y = np.sqrt(-2*np.log(u1))*np.sin(2*np.pi*u2)  + b*x
    im = im + plt.plot([x, x], [y_old, y], color="blue")
    ims.append(im)

ani = animation.ArtistAnimation(fig, ims, interval=400)
ani.save("output.gif", writer="imagemagick")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro', animated=True)

def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

ani = FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init)
plt.show()

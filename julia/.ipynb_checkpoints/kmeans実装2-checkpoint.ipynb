# %% [markdown]
# ### k-means

# %%
function input_data()
    parse_data1= Float64[]
    parse_data2 = Float64[]
    open("./dataset/data_2.txt","r") do fp
        data = readlines(fp)
        for i in 1:length(data)
            push!(parse_data1,parse(Float64,split(data[i], " ")[1]))
            push!(parse_data2 ,parse(Float64,split(data[i], " ")[2]))
        end
    end
    X = [parse_data1 parse_data2]
    return X
end

X = input_data()

using Plots
gr()

function dist(μx, μy, xx, xy)
    # ユークリッド距離
    return sqrt((xx-μx)^2+(μy-xy)^2)
end

# 重心の数
k = 9
# 重心の変数．
μx_old = Float64[]
μy_old = Float64[]
for i in 1:k
    # データの端を乱数の範囲にする．
    # 初期の重心を決める．
    push!(μx_old, rand(minimum(X[:,1]):0.1:maximum(X[:,1])))
    push!(μy_old, rand(minimum(X[:,2]):0.1:maximum(X[:,2])))
end

min = 1000000.0
cluster = 0
center_of_gravity_x = Float64[]
center_of_gravity_y = Float64[]
clusters = Int64[]
n = length(X[:,1])
    
μx_new = Float64[]
μy_new = Float64[]

# 収束判定用の変数
error = 100.0
error_arr = Float64[]

# プロットのgif用変数
plot_data_arr = Any[]
μx_arr = Any[]
μy_arr = Any[]

# 誤差関数が収束すれば終わり．
while error != 0.0  
    clusters = Int64[]
    
     
    for i in 1:n
        # 重心割り当て
        # どの重心に一番近いかを決める．その距離の計算をしている．
        # iには全データが入る．
        min = 100000.0
        for j in 1:k
            distance = dist(μx_old[j], μy_old[j], X[i,1], X[i,2])
            if min > distance
                min = distance
                cluster = j
            end
        end
        push!(clusters, cluster)
    end
    
    plotdata = [X [string(i) for i=clusters];]
    push!(plot_data_arr, plotdata)

    # 主に重心の計算
    for i in 1:k
        cluster_len = length(findin(plotdata[:,3],["$i"]))
        for j in findin(plotdata[:,3],["$i"])
            # 下二行が重心の計算
            push!(center_of_gravity_x,((X[j,1]) / cluster_len))
            push!(center_of_gravity_y,((X[j,2]) / cluster_len))
        end
        push!(μx_new, sum(center_of_gravity_x))
        push!(μy_new, sum(center_of_gravity_y))
        center_of_gravity_x = Float64[]
        center_of_gravity_y = Float64[]
        error = dist(μx_new[i], μy_new[i], μx_old[i], μy_old[i])
        push!(error_arr, error)
    end
    push!(μx_arr, μx_old)
    push!(μy_arr, μy_old)
    μx_old = μx_new
    μy_old = μy_new
    μx_new = Float64[]
    μy_new = Float64[]
end

tmp_x = Float64[]
tmp_y = Float64[]
x_arr = []
y_arr = []

function result(cluster_num)
    tmp_x = Float64[]
    tmp_y = Float64[]
    for p in 1:cluster_num
        result = findin(plotdata[:,3],["$p"])
        # 割り振られたデータをx座標をx_arr, y座標をy_arrにそれぞれ代入する．
        # 重心数が３だったら三つの配列で帰ってくる．
        for i in result
            push!(tmp_x, plotdata[i,1])
            push!(tmp_y, plotdata[i,2])
        end
        push!(x_arr, tmp_x)
        push!(y_arr, tmp_y)
        tmp_x = Float64[]
        tmp_y = Float64[]
    end
end

plotdata = [X [string(i) for i=clusters];]
result(k)
plotdata
# Out:
# 1000×3 Array{Any,2}:
#  -3.93672    -3.5936   "3"
#  -7.03037    -4.30673  "3"
#  -5.61878    -6.48806  "3"
#  -6.36537    -3.86141  "3"
#  -3.42238    -4.81756  "2"
#  -3.96087    -6.21365  "2"
#  -5.2541     -4.79723  "3"
#  -3.94911    -5.78381  "2"
#  -5.35447    -4.52871  "3"
#  -5.46655    -4.0682   "3"
#  -4.74938    -5.46327  "3"
#  -3.27678    -4.64628  "2"
#  -4.15944    -3.41176  "3"
#   ⋮
#  -1.04288     6.2303   "4"
#   1.50573     4.92199  "4"
#   0.99633     5.6953   "4"
#  -0.255848    4.59955  "5"
#   0.0165902   4.76575  "5"
#  -1.09301     6.4878   "4"
#   0.349573    5.30376  "4"
#   0.225971    3.7339   "5"
#   0.947491    7.34555  "4"
#  -0.591647    6.59899  "4"
#   1.44914     4.65748  "5"
#  -1.62489     6.74928  "4"

# %%
function result2(cluster_num)
    tmp_x = Float64[]
    tmp_y = Float64[]
    x_arr = []
    y_arr = []
    @gif for m in 1:length(plot_data_arr)
        plotdata = plot_data_arr[m]
        μx_old = μx_arr[m]
        μy_old = μy_arr[m]
        for p in 1:cluster_num
            result = findin(plotdata[:,3],["$p"])
            # 割り振られたデータをx座標をx_arr, y座標をy_arrにそれぞれ代入する．
            # 重心数が３だったら三つの配列で帰ってくる．
            for i in result
                push!(tmp_x, plotdata[i,1])
                push!(tmp_y, plotdata[i,2])
            end
            push!(x_arr, tmp_x)
            push!(y_arr, tmp_y)
            tmp_x = Float64[]
            tmp_y = Float64[]
        end
        scatter(x_arr, y_arr)
        scatter!(μx_old, μy_old,label="center")
        x_arr = []
        y_arr = []
        end every 1
end
result2(k)
# Out:
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# WARNING: Skipped marker arg *.
# INFO: Saved animation to /Users/noriakioshita/Github/julia/ml_page/julia/tmp.gif
# Plots.AnimatedGif("/Users/noriakioshita/Github/julia/ml_page/julia/tmp.gif")

# %%
?scatter()
# Out:
# No documentation found.
#
# `Plots.scatter` is a `Function`.
#
# ```
# # 1 method for generic function "scatter":
# scatter(args...; kw...) in Plots at /Users/noriakioshita/.julia/v0.6/RecipesBase/src/RecipesBase.jl:381
# ```

# %%
length(plot_data_arr)
# Out:
# 16

# %%
scatter(x_arr, y_arr)
scatter!(μx_old, μy_old,label="center")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0200)" points="
# 36.1567,375.869 580.315,375.869 580.315,11.811 36.1567,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0202">
#     <rect x="36" y="11" width="545" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.6,375.869 101.6,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   197.186,375.869 197.186,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.772,375.869 292.772,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   388.358,375.869 388.358,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   483.943,375.869 483.943,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   579.529,375.869 579.529,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,310.968 580.315,310.968
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,227.704 580.315,227.704
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,144.439 580.315,144.439
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,61.1747 580.315,61.1747
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 36.1567,11.811
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.6,375.869 101.6,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   197.186,375.869 197.186,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.772,375.869 292.772,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   388.358,375.869 388.358,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   483.943,375.869 483.943,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   579.529,375.869 579.529,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567
#   139.476,370.776 143.377,372.941 147.278,332.946 151.179,341.089 155.081,346.614 158.982,322.196 162.883,349.027 166.784,333.875 170.685,369.508 174.587,362.322
#   178.488,373.592 182.389,341.926 186.29,350.428 190.192,345.135 194.093,348.531 197.994,360.33

# %% [markdown]
# ### k-means++

# %%
function input_data()
    parse_data1= Float64[]
    parse_data2 = Float64[]
    open("./dataset/data_2.txt","r") do fp
        data = readlines(fp)
        for i in 1:length(data)
            push!(parse_data1,parse(Float64,split(data[i], " ")[1]))
            push!(parse_data2 ,parse(Float64,split(data[i], " ")[2]))
        end
    end
    X = [parse_data1 parse_data2]
    return X
end

X = input_data()
n = length(X[:,1])

using Plots
gr()

function dist(μx, μy, xx, xy)
    return sqrt((xx-μx)^2+(μy-xy)^2)
end

# 重心の数
k = 5
# 重心の変数．
μx_old = Float64[]
μy_old = Float64[]

DX = Float64[]
function centroid()
    # データ点からランダムに選びそれを重心とする．
    z1 = rand(1:1:length(X[:,1]))
    push!(μx_old, X[z1,1])
    push!(μy_old, X[z1,2])
    DX = Float64[]
    max = 0
    max_num = 0
    
    # データ点との距離を代入する．
    for i in 1:n
        Dx = dist(X[i,1], X[i,2], X[z1,1], X[z1,2])
        push!(DX, Dx)
        for i in 1:k
            max = 0
            for j in 1:n
                Dx = dist(X[j,1], X[j,2], X[z1,1], X[z1,2])
                if max < Dx
                    max = Dx^2 / sum(DX)^2
                    max_num = j
                end
            end
            push!(μx_old, X[max_num,1])
            push!(μy_old, X[max_num,2])
        end
    end
    
"    for i in 2:k
        max = 0
        for j in 1:n
            Dx = dist(X[j,1], X[j,2], X[z1,1], X[z1,2])
            if max < Dx
                max = Dx^2 / sum(DX)^2
                max_num = j
            end
        end
        push!(μx_old, X[max_num,1])
        push!(μy_old, X[max_num,2])
    end"
end

centroid()


min = 1000000.0
cluster = 0
center_of_gravity_x = Float64[]
center_of_gravity_y = Float64[]
clusters = Int64[]
n = length(X[:,1])
    
μx_new = Float64[]
μy_new = Float64[]

# 収束判定用の変数
error = 100.0
error_arr = Float64[]

# 誤差関数が収束すれば終わり．
while error != 0.0  
    clusters = Int64[]
    
     
    for i in 1:n
        # 重心割り当て
        # どの重心に一番近いかを決める．その距離の計算をしている．
        # iには全データが入る．
        min = 100000.0
        for j in 1:k
            distance = dist(μx_old[j], μy_old[j], X[i,1], X[i,2])
            if min > distance
                min = distance
                cluster = j
            end
        end
        push!(clusters, cluster)
    end
    
    plotdata = [X [string(i) for i=clusters];]
    
    # 主に重心の計算
    for i in 1:k
        cluster_len = length(findin(plotdata[:,3],["$i"]))
        for j in findin(plotdata[:,3],["$i"])
            # 下二行が重心の計算
            push!(center_of_gravity_x,((X[j,1]) / cluster_len))
            push!(center_of_gravity_y,((X[j,2]) / cluster_len))
        end
        push!(μx_new, sum(center_of_gravity_x))
        push!(μy_new, sum(center_of_gravity_y))
        center_of_gravity_x = Float64[]
        center_of_gravity_y = Float64[]
        error = dist(μx_new[i], μy_new[i], μx_old[i], μy_old[i])
        push!(error_arr, error)
    end
    μx_old = μx_new
    μy_old = μy_new
    μx_new = Float64[]
    μy_new = Float64[]
end

tmp_x = Float64[]
tmp_y = Float64[]
x_arr = []
y_arr = []

function result(cluster_num)
    tmp_x = Float64[]
    tmp_y = Float64[]
    for p in 1:cluster_num
        result = findin(plotdata[:,3],["$p"])
        # 割り振られたデータをx座標をx_arr, y座標をy_arrにそれぞれ代入する．
        # 重心数が３だったら三つの配列で帰ってくる．
        for i in result
            push!(tmp_x, plotdata[i,1])
            push!(tmp_y, plotdata[i,2])
        end
        push!(x_arr, tmp_x)
        push!(y_arr, tmp_y)
        tmp_x = Float64[]
        tmp_y = Float64[]
    end
end

plotdata = [X [string(i) for i=clusters];]

result(k)
plotdata
# Out:
# 1000×3 Array{Any,2}:
#  -3.93672    -3.5936   "2"
#  -7.03037    -4.30673  "2"
#  -5.61878    -6.48806  "2"
#  -6.36537    -3.86141  "2"
#  -3.42238    -4.81756  "2"
#  -3.96087    -6.21365  "2"
#  -5.2541     -4.79723  "2"
#  -3.94911    -5.78381  "2"
#  -5.35447    -4.52871  "2"
#  -5.46655    -4.0682   "2"
#  -4.74938    -5.46327  "2"
#  -3.27678    -4.64628  "2"
#  -4.15944    -3.41176  "2"
#   ⋮
#  -1.04288     6.2303   "2"
#   1.50573     4.92199  "3"
#   0.99633     5.6953   "3"
#  -0.255848    4.59955  "3"
#   0.0165902   4.76575  "3"
#  -1.09301     6.4878   "2"
#   0.349573    5.30376  "3"
#   0.225971    3.7339   "3"
#   0.947491    7.34555  "3"
#  -0.591647    6.59899  "3"
#   1.44914     4.65748  "3"
#  -1.62489     6.74928  "2"

# %%
scatter(x_arr, y_arr)
scatter!(μx_old, μy_old,label="center")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 36.1567,375.869 580.315,375.869 580.315,11.811 36.1567,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0802">
#     <rect x="36" y="11" width="545" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.6,375.869 101.6,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   197.186,375.869 197.186,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.772,375.869 292.772,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   388.358,375.869 388.358,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   483.943,375.869 483.943,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   579.529,375.869 579.529,11.811
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,310.968 580.315,310.968
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,227.704 580.315,227.704
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,144.439 580.315,144.439
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,61.1747 580.315,61.1747
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 36.1567,11.811
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.6,375.869 101.6,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   197.186,375.869 197.186,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.772,375.869 292.772,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   388.358,375.869 388.358,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   483.943,375.869 483.943,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   579.529,375.869 579.529,370.408
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,310.968 44.3191,310.968
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,227.704 44.3191,227.704
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,144.439 44.3191,144.439
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,61.1747 44.3191,61.1747
#   "/>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.6, 389.669)" x="101.6" y="389.669">-5</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 197.186, 389.669)" x="197.186" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.772, 389.669)" x="292.772" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 388.358, 389.669)" x="388.358" y="389.669">10</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 483.943, 389.669)" x="483.943" y="389.669">15</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 579.529, 389.669)" x="579.529" y="389.669">20</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.1567,
)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,244.69 77.8186,271.854 116.472,223.37 155.126,370.156 193.779,289.38 232.433,311.918 271.086,375.72 309.74,345.024 348.394,373.401 387.047,370.36
#   425.701,359.796 464.354

# %%
using PyCall
@pyimport sklearn.cluster as kcluster

# %%
# クラスタを3つでやる．
n_cluster = 10
y_km = kcluster.KMeans(n_clusters=n_cluster, init="k-means++", n_init=10, max_iter=300, tol=1e-04, random_state=0)[:fit_predict](X) +1
plotdata = [X [string(i) for i=y_km];]
# Out:
# 1000×3 Array{Any,2}:
#  -3.93672    -3.5936   "4"
#  -7.03037    -4.30673  "4"
#  -5.61878    -6.48806  "4"
#  -6.36537    -3.86141  "4"
#  -3.42238    -4.81756  "4"
#  -3.96087    -6.21365  "4"
#  -5.2541     -4.79723  "4"
#  -3.94911    -5.78381  "4"
#  -5.35447    -4.52871  "4"
#  -5.46655    -4.0682   "4"
#  -4.74938    -5.46327  "4"
#  -3.27678    -4.64628  "4"
#  -4.15944    -3.41176  "4"
#   ⋮
#  -1.04288     6.2303   "3"
#   1.50573     4.92199  "3"
#   0.99633     5.6953   "3"
#  -0.255848    4.59955  "3"
#   0.0165902   4.76575  "3"
#  -1.09301     6.4878   "3"
#   0.349573    5.30376  "3"
#   0.225971    3.7339   "3"
#   0.947491    7.34555  "3"
#  -0.591647    6.59899  "3"
#   1.44914     4.65748  "3"
#  -1.62489     6.74928  "3"

# %%
x_arr = []
y_arr = []
result(n_cluster)
scatter(x_arr, y_arr)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0200)" points="
# 36.1567,375.869 580.315,375.869 580.315,11.811 36.1567,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0202">
#     <rect x="36" y="11" width="545" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.6,375.869 101.6,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   197.186,375.869 197.186,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.772,375.869 292.772,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   388.358,375.869 388.358,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   483.943,375.869 483.943,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   579.529,375.869 579.529,11.811
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,310.968 580.315,310.968
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,227.704 580.315,227.704
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,144.439 580.315,144.439
#   "/>
# <polyline clip-path="url(#clip0202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   36.1567,61.1747 580.315,61.1747
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,375.869 36.1567,11.811
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.6,375.869 101.6,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   197.186,375.869 197.186,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.772,375.869 292.772,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   388.358,375.869 388.358,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   483.943,375.869 483.943,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   579.529,375.869 579.529,370.408
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,310.968 44.3191,310.968
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,227.704 44.3191,227.704
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,144.439 44.3191,144.439
#   "/>
# <polyline clip-path="url(#clip0200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   36.1567,61.1747 44.3191,61.1747
#   "/>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.6, 389.669)" x="101.6" y="389.669">-5</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 197.186, 389.669)" x="197.186" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.772, 389.669)" x="292.772" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 388.358, 389.669)" x="388.358" y="389.669">10</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 483.943, 389.669)" x="483.943" y="389.669">15</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 579.529, 389.669)" x="579.529" y="389.669">20</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.1567, 315.468)" x="30.1567" y="315.468">-10</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.1567, 232.204)" x="30.1567" y="232.204">-5</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.1567, 148.939)" x="30.1567" y="148.939">0</text>
# </g>
# <g clip-path="url(#clip0200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.1567, 65.6747)" x="30.1567" y="65.6747">5</text>
# </g>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="452.065" cy="177.916" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="452.065" cy="177.916" r="3"/>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="463.153" cy="200.239" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="463.153" cy="200.239" r="3"/>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="488.248" cy="168.919" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="488.248" cy="168.919" r="3"/>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="456.041" cy="136.485" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="456.041" cy="136.485" r="3"/>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="480.236" cy="219.486" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="480.236" cy="219.486" r="3"/>
# <circle clip-path="url(#clip0202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="451.738" cy="216.993" r="4"/>
# <circle clip-path="url(#clip0202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="451.738" cy="

# %%
function input_data()
    parse_data1= Float64[]
    parse_data2 = Float64[]
    open("./dataset/data_1.txt","r") do fp
        data = readlines(fp)
        for i in 1:length(data)
            push!(parse_data1,parse(Float64,split(data[i], " ")[1]))
            push!(parse_data2 ,parse(Float64,split(data[i], " ")[2]))
        end
    end
    X = [parse_data1 parse_data2]
    return X
end

X = input_data()

using Plots
gr()

function dist(μx, μy, xx, xy)
    return sqrt(((xx+xy)-(μx+μy))^2)
end

# 重心の数
k = 3
# 重心の変数．
μx_old = Float64[]
μy_old = Float64[]
for i in 1:k
    # データの端を乱数の範囲にする．
    push!(μx_old,rand(minimum(X[:,1]):0.1:maximum(X[:,1])))
    push!(μy_old,rand(minimum(X[:,2]):0.1:maximum(X[:,2])))
end

min = 1000000.0
cluster = 0
center_of_gravity_x = Float64[]
center_of_gravity_y = Float64[]
clusters = Int64[]
n = length(X[:,1])
    
μx_new = Float64[]
μy_new = Float64[]

# 収束判定用の変数
error = 100.0
error_arr = Float64[]

# 誤差関数が収束すれば終わり．
while error != 0.0  
    clusters = Int64[]
    
    min = 1000000.0 
    for i in 1:n
        # クラスタ割り当て
        # iには全データが入る．
        for j in 1:k
            distance = dist(μx_old[j], μy_old[j], X[i,1],X[i,2])
            if min > distance
                min = distance
                cluster = j
            end
        end
        push!(clusters, cluster)
    end
    
    plotdata = [X [string(i) for i=clusters];]
    
    # クラスタ中心の計算
    for i in 1:k
        cluster_len = length(findin(plotdata[:,3],["$i"]))
        for j in findin(plotdata[:,3],["$i"])
            # 重心の計算
            push!(center_of_gravity_x,((X[j,1]) / cluster_len))
            push!(center_of_gravity_y,((X[j,2]) / cluster_len))
        end
        push!(μx_new, sum(center_of_gravity_x))
        push!(μy_new, sum(center_of_gravity_y))
        center_of_gravity_x = Float64[]
        center_of_gravity_y = Float64[]
        error = dist(μx_new[i],μy_new[i],μx_old[i],μy_old[i])
        push!(error_arr, error)
    end
    μx_old = μx_new
    μy_old = μy_new
    μx_new = Float64[]
    μy_new = Float64[]
end
plotdata = [X [string(i) for i=clusters];]
# Out:
# 300×3 Array{Any,2}:
#  -5.62534    -6.76417  "2"
#  -6.21922    -5.41678  "2"
#  -4.06308    -7.91013  "2"
#  -4.52609    -4.15787  "2"
#  -5.08887    -7.15388  "2"
#  -5.32479    -3.55313  "2"
#  -3.71644    -3.9373   "2"
#  -4.96026    -4.28604  "2"
#  -4.80726    -4.84573  "2"
#  -6.2293     -5.45225  "2"
#  -4.73248    -6.07151  "2"
#  -4.57423    -4.81333  "2"
#  -6.91621    -5.01012  "2"
#   ⋮
#  -0.447324    5.24562  "1"
#  -0.0852852   3.57781  "1"
#   0.508129    5.74799  "1"
#  -1.07802     3.90862  "1"
#  -0.212547    5.04975  "1"
#   0.655446    5.78681  "1"
#  -0.59045     4.85202  "1"
#   0.481862    4.43283  "1"
#  -1.22335     5.85245  "1"
#   1.05789     4.09235  "1"
#   1.2708      5.64577  "1"
#  -0.772036    4.3587   "1"

# %%
tmp_x = Float64[]
tmp_y = Float64[]
x_arr = []
y_arr = []

function result(cluster_num)
    tmp_x = Float64[]
    tmp_y = Float64[]
    for p in 1:cluster_num
        result = findin(plotdata[:,3],["$p"])
        for i in result
            for j in 1:2
                push!(tmp_x, plotdata[i,1])
                push!(tmp_y, plotdata[i,2])
            end
        end
        push!(x_arr, tmp_x)
        push!(y_arr, tmp_y)
        tmp_x = Float64[]
        tmp_y = Float64[]
    end
end
# Out:
# result (generic function with 1 method)

# %%
result(3)

# %%
scatter(x_arr, y_arr)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 29.4661,375.869 580.315,375.869 580.315,11.811 29.4661,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2402">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.499,375.869 121.499,11.811
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.356,375.869 249.356,11.811
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   377.213,375.869 377.213,11.811
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   505.07,375.869 505.07,11.811
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,310.27 580.315,310.27
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,243.321 580.315,243.321
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,176.372 580.315,176.372
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,109.423 580.315,109.423
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,42.4737 580.315,42.4737
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,375.869 29.4661,11.811
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.499,375.869 121.499,370.408
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.356,375.869 249.356,370.408
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   377.213,375.869 377.213,370.408
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   505.07,375.869 505.07,370.408
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,310.27 37.7289,310.27
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,243.321 37.7289,243.321
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,176.372 37.7289,176.372
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,109.423 37.7289,109.423
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,42.4737 37.7289,42.4737
#   "/>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.499, 389.669)" x="121.499" y="389.669">-5</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.356, 389.669)" x="249.356" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 377.213, 389.669)" x="377.213" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 505.07, 389.669)" x="505.07" y="389.669">10</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 314.77)" x="23.4661" y="314.77">-6</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 247.821)" x="23.4661" y="247.821">-3</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 180.872)" x="23.4661" y="180.872">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 113.923)" x="23.4661" y="113.923">3</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 46.9737)" x="23.4661" y="46.9737">6</text>
# </g>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="498.898" cy="278.654" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="498.898" cy="278.654" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="498.898" cy="278.654" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="498.898" cy="278.654" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="498.091" cy="299.811" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="498.091" cy="299.811" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="498.091" cy="299.811" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="498.091" cy="299.811" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="514.965" cy="249.519" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="514.965" cy="249.519" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="514.965" cy="249.519" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="514.965" cy="249.519" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="478.558" cy="312.003" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="478.558" cy="312.003" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="478.558" cy="312.003" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="478.558" cy="312.003" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none

# %%
plot(error_arr)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 39.1651,375.869 580.315,375.869 580.315,11.811 39.1651,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5402">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,375.869 39.1651,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   147.395,375.869 147.395,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   255.625,375.869 255.625,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   363.855,375.869 363.855,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   472.085,375.869 472.085,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.869 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,300.505 580.315,300.505
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,225.141 580.315,225.141
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,149.778 580.315,149.778
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,74.414 580.315,74.414
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 39.1651,11.811
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 39.1651,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.395,375.869 147.395,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   255.625,375.869 255.625,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   363.855,375.869 363.855,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   472.085,375.869 472.085,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.869 580.315,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 47.2823,375.869
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,300.505 47.2823,300.505
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,225.141 47.2823,225.141
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,149.778 47.2823,149.778
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,74.414 47.2823,74.414
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.1651, 389.669)" x="39.1651" y="389.669">1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 147.395, 389.669)" x="147.395" y="389.669">2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 255.625, 389.669)" x="255.625" y="389.669">3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 363.855, 389.669)" x="363.855" y="389.669">4</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 472.085, 389.669)" x="472.085" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.669)" x="580.315" y="389.669">6</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 380.369)" x="33.1651" y="380.369">0.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 305.005)" x="33.1651" y="305.005">2.5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 229.641)" x="33.1651" y="229.641">5.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 154.278)" x="33.1651" y="154.278">7.5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 78.914)" x="33.1651" y="78.914">10.0</text>
# </g>
# <polyline clip-path="url(#clip5402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,114.62 147.395,350.775 255.625,177.898 363.855,369.867 472.085,11.811 580.315,375.869
#   "/>
# <polygon clip-path="url(#clip5400)" points="
# 489.608,62.931 562.315,62.931 562.315,32.691 489.608,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   489.608,62.931 562.315,62.931 562.315,32.691 489.608,32.691 489.608,62.931
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   495.608,47.811 531.608,47.811
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-si

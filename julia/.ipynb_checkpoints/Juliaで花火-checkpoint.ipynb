# %%
using Plots

# %%
function get_rotation_matrix(rad)
    rot = [cos(rad) -sin(rad);　sin(rad) cos(rad)]
    return rot
end
# Out:
# get_rotation_matrix (generic function with 1 method)

# %%
base_point1 = Float64[1. 0.; 0. 1]
base_point2 = Float64[0.75 0.; 0. 0.75]
base_point3 = Float64[0.5 0.; 0. 0.5]
base_point4 = Float64[0.25 0.; 0. 0.25]
base_point5 = Float64[0. 0.; 0. 0.]

x_points1 = []
y_points1 = []
x_points2 = []
y_points2 = []
x_points3 = []
y_points3 = []
x_points4 = []
y_points4 = []
x_points5 = []
y_points5 = []

function plotting()
    for i in 1:12
        deg = i * 30
        rad = deg * π / 180
        rot = get_rotation_matrix(rad)
        
        rotated1 =[rot* base_point1]
        rotated2 =[rot* base_point2]
        rotated3 =[rot* base_point3]
        rotated4 =[rot* base_point4]
        rotated5 =[rot* base_point5]
            
        push!(x_points1, rotated1[1][1])
        push!(y_points1, rotated1[1][2])
        push!(x_points2, rotated2[1][1])
        push!(y_points2, rotated2[1][2])
        push!(x_points3, rotated3[1][1])
        push!(y_points3, rotated3[1][2])
        push!(x_points4, rotated4[1][1])
        push!(y_points4, rotated4[1][2])
        push!(x_points5, rotated5[1][1])
        push!(y_points5, rotated5[1][2])
    end
end
# Out:
# plotting (generic function with 1 method)

# %%
plotting()
plot([x_points1, x_points2, x_points3, x_points4, x_points5], [y_points1, y_points2, y_points3, y_points4, y_points5], st=:scatter, size=(400,400))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="400" viewBox="0 0 400 400">
# <defs>
#   <clipPath id="clip7500">
#     <rect x="0" y="0" width="400" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 400,400 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7501">
#     <rect x="80" y="40" width="281" height="281"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 39.1436,371.594 380.315,371.594 380.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7502">
#     <rect x="39" y="11" width="342" height="361"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.7994,371.594 48.7994,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   129.264,371.594 129.264,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   209.729,371.594 209.729,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   290.194,371.594 290.194,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   370.659,371.594 370.659,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,361.412 380.315,361.412
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,276.557 380.315,276.557
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,191.703 380.315,191.703
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,106.848 380.315,106.848
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,21.9936 380.315,21.9936
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,371.594 380.315,371.594
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,371.594 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.7994,371.594 48.7994,366.197
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   129.264,371.594 129.264,366.197
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   209.729,371.594 209.729,366.197
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   290.194,371.594 290.194,366.197
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   370.659,371.594 370.659,366.197
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,361.412 44.2612,361.412
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,276.557 44.2612,276.557
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,191.703 44.2612,191.703
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,106.848 44.2612,106.848
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,21.9936 44.2612,21.9936
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.7994, 384.394)" x="48.7994" y="384.394">-1.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 129.264, 384.394)" x="129.264" y="384.394">-0.5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 209.729, 384.394)" x="209.729" y="384.394">0.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 290.194, 384.394)" x="290.194" y="384.394">0.5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 370.659, 384.394)" x="370.659" y="384.394">1.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 365.912)" x="35.1436" y="365.912">-1.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 281.057)" x="35.1436" y="281.057">-0.5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 196.203)" x="35.1436" y="196.203">0.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 111.348)" x="35.1436" y="111.348">0.5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 26.4936)" x="35.1436" y="26.4936">1.0</text>
# </g>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="349.099" cy="106.848" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="349.099" cy="106.848" r="3"/>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="290.194" cy="44.7303" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="290.194" cy="44.7303" r="3"/>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="209.729" cy="21.9936" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="209.729" cy="21.9936" r="3"/>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="129.264" cy="44.7303" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="129.264" cy="44.7303" r="3"/>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="70.3599" cy="106.848" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="70.3599" cy="106.848" r="3"/>
# <circle clip-path="url(#clip7502)" style="fill:#000000; stroke:none; fill-opacity:1" cx="48.7994" cy="191.703" r="4"/>
# <circle clip-path="url(#clip7502)" style="fill:#009af9; stroke:none; fill-o

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import umap
# %matplotlib inline
sns.set(style='white', rc={'figure.figsize':(12,8)})

# %%
np.random.seed(42)
data = np.random.rand(800, 4)

# %%
fit = umap.UMAP()
# %time u = fit.fit_transform(data)
# Out:
# CPU times: user 1.55 s, sys: 100 ms, total: 1.65 s
# Wall time: 1.77 s

# %%
plt.scatter(u[:,0], u[:,1], c=data)

# %%
def draw_umap(n_neighbors=15, min_dist=0.1, n_components=2, metric='euclidean', title=''):
    fit = umap.UMAP(
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        n_components=n_components,
        metric=metric
    )
    u = fit.fit_transform(data);
    fig = plt.figure()
    if n_components == 1:
        ax = fig.add_subplot(111)
        ax.scatter(u[:,0], range(len(u)), c=data)
    if n_components == 2:
        ax = fig.add_subplot(111)
        ax.scatter(u[:,0], u[:,1], c=data)
    if n_components == 3:
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(u[:,0], u[:,1], u[:,2], c=data)
    plt.title(title, fontsize=18)

# %%
for n in (2, 5, 10, 20, 50, 100, 200):
    draw_umap(n_neighbors=n, title='n_neighbors = {}'.format(n))

# %%
for d in (0.0, 0.1, 0.25, 0.5, 0.8, 0.99):
    draw_umap(min_dist=d, title='min_dist = {}'.format(d))

# %%
draw_umap(n_components=1, title='n_components = 1')

# %%
draw_umap(n_components=3, title='n_components = 3')

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource
from bokeh.palettes import Category10

import umap
from sklearn.datasets import load_digits

digits = load_digits()
embedding = umap.UMAP().fit_transform(digits.data)

output_file("digits.html")

targets = [str(d) for d in digits.target_names]

source = ColumnDataSource(dict(
    x = [e[0] for e in embedding],
    y = [e[1] for e in embedding],
    label = [targets[d] for d in digits.target]
))

cmap = CategoricalColorMapper(factors=targets, palette=Category10[10])

p = figure(title="test umap")
p.circle(x='x',
         y='y',
         source=source,
         color={"field": 'label', "transform": cmap},
         legend='label')
show(p)

# %%
print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
output_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb80bf666356> in <module>()
# ----> 1 output_notebook()
#
# NameError: name 'output_notebook' is not defined

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource
from bokeh.palettes import Category10
from bokeh.io import output_notebook

import umap
from sklearn.datasets import load_iris

iris = load_iris()
embedding = umap.UMAP(n_neighbors=50,
                      alpha=0.5,
                      init="random",
                      min_dist=0.001)\
                .fit_transform(iris.data)

#output_file("iris.html")
output_notebook()


targets = [str(d) for d in iris.target_names]

source = ColumnDataSource(dict(
    x=[e[0] for e in embedding],
    y=[e[1] for e in embedding],
    label=[targets[d] for d in iris.target]
))

cmap = CategoricalColorMapper(factors=targets, palette=Category10[10])

p = figure(title="Test UMAP on Iris dataset")
p.circle(x='x',
         y='y',
         source=source,
         color={"field": 'label', "transform": cmap},
         legend='label')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab34d0d5-7155-412f-b9ef-ff437bb4244f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4827b41-738c-427b-aee5-76a39a8a16f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f4827b41-738c-427b-aee5-76a39a8a16f0");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4827b41-738c-427b-aee5-76a39a8a16f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4827b41-738c-427b-aee5-76a39a8a16f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"19676d17-975d-4b5d-ac4c-ce54a0d8f9b8":{"roots":{"references":[{"attributes":{},"id":"fc589619-eabc-4bcb-aad9-1288085a195d","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cfd46887-e717-4181-8a87-34564ce68e34","type":"BoxAnnotation"},{"attributes":{},"id":"9a9b73ef-e15b-4507-83e2-b3570e0cb8da","type":"ResetTool"},{"attributes":{"items":[{"id":"774464fa-75ea-4661-af19-a0dce6488f04","type":"LegendItem"}],"plot":{"id":"8684c2dc-f25e-4158-a8c6-06046794fe15","subtype":"Figure","type":"Plot"}},"id":"e41e1621-8ab9-4f7d-86ac-e709ddd3a744","type":"Legend"},{"attributes":{"formatter":{"id":"b67d975f-08d5-4127-aded-2923aa4a12a0","type":"BasicTickFormatter"},"plot":{"id":"8684c2dc-f25e-4158-a8c6-06046794fe15","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc589619-eabc-4bcb-aad9-1288085a195d","type":"BasicTicker"}},"id":"80d02a54-c241-4482-ace2-7566a82c720a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"33c656c1-c224-496c-9cd3-1f2e8f4f4244","type":"PanTool"},{"id":"0fc589f3-8ffa-4db2-a009-bc77d884eb7c","type":"WheelZoomTool"},{"id":"4a2639ab-a1f3-4f88-a9a6-35804cdcfe5a","type":"BoxZoomTool"},{"id":"b3e2359f-0daf-4b67-ab4d-81c5cca2b2af","type":"SaveTool"},{"id":"9a9b73ef-e15b-4507-83e2-b3570e0cb8da","type":"ResetTool"},{"id":"cf521aee-f4a8-484d-bed7-a1c568b669e7","type":"HelpTool"}]},"id":"0451d3d6-e13d-4502-b15d-765b18eeb2d7","type":"Toolbar"},{"attributes":{"below":[{"id":"bb548405-5f0f-405c-8d61-6a039137f4c4","type":"LinearAxis"}],"left":[{"id":"80d02a54-c241-4482-ace2-7566a82c720a","type":"LinearAxis"}],"renderers":[{"id":"bb548405-5f0f-405c-8d61-6a039137f4c4","type":"LinearAxis"},{"id":"5e35ab94-c617-40cf-8dc8-dbfb88d46bd3","type":"Grid"},{"id":"80d02a54-c241-4482-ace2-7566a82c720a","type":"LinearAxis"},{"id":"6230f423-e17c-401c-b311-2a1dfaebb95d","type":"Grid"},{"id":"cfd46887-e717-4181-8a87-34564ce68e34","type":"BoxAnnotation"},{"id":"e41e1621-8ab9-4f7d-86ac-e709ddd3a744","type":"Legend"},{"id":"925d6fe1-6da1-46c9-b7e4-5b5cc02d96d6","type":"GlyphRenderer"}],"title":{"id":"3db1b76a-4a8a-45a4-82ce-b0bb415f44c4","type":"Title"},"toolbar":{"id":"0451d3d6-e13d-4502-b15d-765b18eeb2d7","type":"Toolbar"},"x_range":{"id":"18f2ba17-2b8c-4666-8fc5-2c6a9c359310","type":"DataRange1d"},"x_scale":{"id":"4b72f1d6-8ab2-412a-9b57-914260770447","type":"LinearScale"},"y_range":{"id":"e0e8c27b-c045-4c9e-96f5-f894f11201a0","type":"DataRange1d"},"y_scale":{"id":"15c4413d-2064-4f45-892e-1446eb121ff0","type":"LinearScale"}},"id":"8684c2dc-f25e-4158-a8c6-06046794fe15","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"15c4413d-2064-4f45-892e-1446eb121ff0","type":"LinearScale"},{"attributes":{"plot":{"id":"8684c2dc-f25e-4158-a8c6-06046794fe15","subtype":"Figure","type":"Plot"},"ticker":{"id":"01e3daf0-fc49-4080-b27c-24e5c5c0d0c8","type":"BasicTicker"}},"id":"5e35ab94-c617-40cf-8dc8-dbfb88d46bd3","type":"Grid"},{"attributes":{"callback":null},"id":"e0e8c27b-c045-4c9e-96f5-f894f11201a0","type":"DataRange1d"},{"attributes":{},"id":"33c656c1-c224-496c-9cd3-1f2e8f4f4244","type":"PanTool"},{"attributes":{"overlay":{"id":"cfd46887-e717-4181-8a87-34564ce68e34","type":"BoxAnnotation"}},"id":"4a2639ab-a1f3-4f88-a9a6-35804cdcfe5a","type":"BoxZoomTool"},{"attributes":{"factors":["setosa","versicolor","virginica"],"palette":["#1f77b4","#ff7f0e","#2ca02c","#d62728","#9467bd","#8c564b","#e377c2","#7f7f7f","#bcbd22","#17becf"]},"id":"a1373276-b695-4871-80b0-f04559893939","type":"CategoricalColorMapper"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x" ...

# %%
import numpy as np
from PIL import Image
import os

data_dir_path = u"./dataset/coil-20-unproc/"
file_list = os.listdir(r'./dataset/coil-20-unproc/')

for file_name in file_list:
    img = Image.open('./dataset/coil-20-unproc/obj1__0.png').convert('RGBA')
    arr = np.array(img)

# %%
# Out:
# array([[[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]],
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]],
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]],
#
#        ...,
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]],
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]],
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255]]], dtype=uint8)
